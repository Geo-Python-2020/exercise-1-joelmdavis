# %%
1+1
# Out:
# 2

# %% [markdown]
# A comment!

# %%
#Test comment

# %%
ice_cream_rating = 10

# %%
sleeping_rating = 9

# %%
input(first_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ceab4e5008a2> in <module>
# ----> 1 input(first_name)
#
# NameError: name 'first_name' is not defined

# %%
input("first_name")
# Out:
# first_name Joel
# 'Joel'

# %%
input("last_name")
# Out:
# last_name Davis
# 'Davis'

# %%
my_name = input("first_name") + " " + input("last_name")
# Out:
# first_name Joel
# last_name Davis

# %%
print(my_name)
# Out:
# Joel Davis

# %%
happiness_rating = (ice_cream_rating + sleeping_rating)/2

# %%
print(happiness_rating)
# Out:
# 9.5

# %%
type(ice_cream_rating, first_name, happiness_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-964790debc98> in <module>
# ----> 1 type(ice_cream_rating, first_name, happiness_rating)
#
# NameError: name 'first_name' is not defined

# %%
type(ice_cream_rating)
# Out:
# int

# %%
print("first_name")
# Out:
# first_name

# %%
print(first_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1288399a246b> in <module>
# ----> 1 print(first_name)
#
# NameError: name 'first_name' is not defined

# %%
input("first_name")
# Out:
# first_name Joel
# 'Joel'

# %%
type(ice_cream_rating, first_name, happiness_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-964790debc98> in <module>
# ----> 1 type(ice_cream_rating, first_name, happiness_rating)
#
# NameError: name 'first_name' is not defined

# %%
print(first_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1288399a246b> in <module>
# ----> 1 print(first_name)
#
# NameError: name 'first_name' is not defined

# %%
type(happiness_rating)
# Out:
# float

# %%
first_name = input('what is your first name?')
# Out:
# what is your first name? Joel

# %%
type(ice_cream_rating, first_name, happiness_rating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-964790debc98> in <module>
# ----> 1 type(ice_cream_rating, first_name, happiness_rating)
#
# TypeError: type.__new__() argument 1 must be str, not int

# %%
type(ice_cream_rating)
# Out:
# int

# %%
type(first_name)
# Out:
# str

# %%
type(happiness_rating)
# Out:
# float

# %%
print(type(ice_cream_rating, first_name, happiness_rating))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0d1e4953afb2> in <module>
# ----> 1 print(type(ice_cream_rating, first_name, happiness_rating))
#
# TypeError: type.__new__() argument 1 must be str, not int

# %%
type(ice_cream_rating), type(first_name), type(happiness_rating)
# Out:
# (int, str, float)

# %%
type(ice_cream_rating, happiness_rating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-4f5c72b193a4> in <module>
# ----> 1 type(ice_cream_rating, happiness_rating)
#
# TypeError: type() takes 1 or 3 arguments

# %%
print('my name is ', first_name, ' and I give eating ice cream a score of ', ice_cream_rating, ' out of 10')
# Out:
# my name is  Joel  and I give eating ice cream a score of  10  out of 10

# %%
print('I am ', first_name, ' ', last_name, ' and my sleeping enjoyment rating is', sleeping_rating, '/10!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-831dcd246a8a> in <module>
# ----> 1 print('I am ', first_name, ' ', last_name, ' and my sleeping enjoyment rating is', sleeping_rating, '/10!')
#
# NameError: name 'last_name' is not defined

# %%
last_name = input('what is your last name?')
# Out:
# what is your last name? Davis

# %%
print('I am ', first_name, ' ', last_name, ' and my sleeping enjoyment rating is', sleeping_rating, '/10!')
# Out:
# I am  Joel   Davis  and my sleeping enjoyment rating is 9 /10!

# %%
print('based on the factors above, my happiness rating is ',happiness_rating,' out of 10, or',happiness_rating * 10,'%')
# Out:
# based on the factors above, my happiness rating is  9.5  out of 10, or 95.0 %

# %%
happiness_rating * 10
# Out:
# 95.0
